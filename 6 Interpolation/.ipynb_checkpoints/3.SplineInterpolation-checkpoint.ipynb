# %% [markdown]
# # Spline Interpolation

# %%
from scipy import interpolate
from numpy import polynomial as P

import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %% [markdown]
# The SciPy interpolate module provides several functions and classes for
# performing spline interpolation. For example, we can use the `interpolate.interp1d`
# function, which takes `x` and `y` arrays for the data points as first and second arguments.

# %%
def runge(x):
    return 1/(1 + 25 * x**2)

def runge_interpolate(n):
    x = np.linspace(-1, 1, n + 1)
    p = P.Polynomial.fit(x, runge(x), deg=n)
    return x, p

# %%
# 11 data pounts for interpolation
x = np.linspace(-1, 1, 11)
y = runge(x)

# Prepare interpolation function
f_i = interpolate.interp1d(x, y, kind=3)

# %% [markdown]
# ## Runge’s function with a third-order Spline interpolation using 11 data points

# %%
xx = np.linspace(-1, 1, 100)
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(xx, runge(xx), 'k', lw=1, label="Runge's function")
ax.plot(x, y, 'ro', label='sample points')

ax.plot(xx, f_i(xx), 'r--', lw=2, label='spline order 3')

ax.legend()
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_ylabel(r"$y$", fontsize=18)
ax.set_xlabel(r"$x$", fontsize=18)
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# > Here we used 11 data points and a spline of the third order. We note that the
# interpolant agrees very well with the original function in Figure. Typically spline
# interpolation of order three or less does not suffer from the same type of oscillations that
# we observed with high-order polynomial interpolation, and normally it is sufficient to
# use splines of order three if we have a sufficient number of data points

# %% [markdown]
# ### Spline interpolations of different orders

# %% [markdown]
# Computational Science and Engineering, Gil Strang,
#
# Chapter 3.2 Cubic Splines and Fourth-Order Equations pages 249-250
#
# ![image.png](attachment:0eb7badb-a68b-4b77-aae3-cb0abd8cdd76.png)
#
# > If you interpolate two many values, the
# polynomial will oscillate wildly in between -> example in prev chapter with the Runge’s function together with two high-order polynomial interpolations
#
# ![image.png](attachment:3ab77543-48e3-4fba-9110-1f49339fef12.png)

# %% [markdown]
# > To illustrate the effect of the order of a spline interpolation, consider the problem of
# interpolating the data `(0, 3)`, `(1, 4)`, `(2, 3.5)`, `(3, 2)`, `(4, 1)`, `(5, 1.5)`, `(6, 1.25)`, and `(7, 0.9)` with
# splines of increasing order. We first define the `x` and `y` arrays, and then loop over the
# required spline orders, computing the interpolation and plotting it for each order

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6, 7])
y = np.array([3, 4, 3.5, 2, 1, 1.5, 1.25, 0.9])

xx = np.linspace(x.min(), x.max(), 100)

fig, ax = plt.subplots(figsize=(8, 4))
ax.scatter(x, y)
